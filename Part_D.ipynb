# %% [markdown]
# ### Task: Logistic Regression Explanation & Evaluation
#
# **Prompt Documentation:**
# *   **User Prompt:** "Explain Logistic Regression with Python example using sklearn on SUV dataset."
# *   **Approach:** Since the current notebook uses a student performance dataset, the example used `age` and `previous_gpa` as proxies for the SUV dataset features `Age` and `EstimatedSalary` to demonstrate the logic.
#
# **Implementation Steps:**
# 1.  **Feature Selection:** Identified independent variables (`age`, `previous_gpa`) and the target (`pass_fail`).
# 2.  **Dataset Splitting:** Used `train_test_split` with a 75/25 ratio.
# 3.  **Feature Scaling:** Applied `StandardScaler` to normalize the data.
# 4.  **Model Training:** Initialized and fitted a `LogisticRegression` classifier.
# 5.  **Prediction & Evaluation:** Computed the Confusion Matrix and Accuracy Score.
#
# **Evaluation:**
# *   **Is code correct?** Yes. It correctly utilizes `sklearn` classes, ensures feature scaling (which is critical for Logistic Regression convergence and performance), and uses the standard `fit/predict` API.
# *   **Are steps complete?** Yes. It covers the entire end-to-end workflow from data preparation to model evaluation metrics.
